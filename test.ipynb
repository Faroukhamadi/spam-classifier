# %%
import os
import urllib.request
import tarfile

# %%
DOWNLOAD_ROOT = 'https://spamassassin.apache.org/old/publiccorpus/'
SPAM_PATHS = [
    '20021010_easy_ham.tar.bz2',
    '20021010_hard_ham.tar.bz2',
    '20021010_spam.tar.bz2',
    '20030228_easy_ham.tar.bz2',
    '20030228_easy_ham_2.tar.bz2',
    '20030228_hard_ham.tar.bz2',
    '20030228_spam.tar.bz2',
    '20030228_spam_2.tar.bz2',
    '20050311_spam_2.tar.bz2',
]

# %%
def fetch_spam_data(download_root=DOWNLOAD_ROOT, spam_paths=SPAM_PATHS):
    if not os.path.isdir('data'):
        os.makedirs('data')
    for path in SPAM_PATHS:
        url = DOWNLOAD_ROOT + path
        tgz_path = os.path.join('data', path)
        urllib.request.urlretrieve(url, tgz_path)
        spam_tgz = tarfile.open(tgz_path)
        spam_tgz.extractall(path='data')
    spam_tgz.close()

# %%
fetch_spam_data()

# %%
# %ls data
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 6868-BBB1
#
#  Directory of C:\Users\farou\OneDrive\Bureau\Programming\spam-classifier\data
#
# 03/29/2023  10:26 PM    <DIR>          .
# 03/30/2023  02:32 AM    <DIR>          ..
# 03/30/2023  02:30 AM         1,677,144 20021010_easy_ham.tar.bz2
# 03/30/2023  02:30 AM         1,021,126 20021010_hard_ham.tar.bz2
# 03/30/2023  02:30 AM         1,192,582 20021010_spam.tar.bz2
# 03/30/2023  02:31 AM         1,612,216 20030228_easy_ham.tar.bz2
# 03/30/2023  02:31 AM         1,077,892 20030228_easy_ham_2.tar.bz2
# 03/30/2023  02:31 AM         1,029,898 20030228_hard_ham.tar.bz2
# 03/30/2023  02:31 AM         1,183,768 20030228_spam.tar.bz2
# 03/30/2023  02:31 AM         2,059,563 20030228_spam_2.tar.bz2
# 03/30/2023  02:31 AM         2,059,029 20050311_spam_2.tar.bz2
# 02/28/2003  12:04 PM    <DIR>          easy_ham
# 02/28/2003  12:04 PM    <DIR>          easy_ham_2
# 12/16/2004  08:38 PM    <DIR>          hard_ham
# ...

# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from collections import Counter

# %%
# x = np.loadtxt('data/easy_ham/00001.7c53336b37003a9286aba55d2945844c', dtype='str')
x = []
with open('data/easy_ham/00001.7c53336b37003a9286aba55d2945844c') as f:
    x.append(f.read().split())
len(x[0])
x_spam = []
x_ham = []

# %%
path = os.path.join(os.getcwd(), 'data')
for dirname in os.listdir(path):
    if 'tar' not in dirname:
        if 'spam' in dirname:
            for filename in os.listdir(os.path.join(path, dirname)):
                abs_path = os.path.join(path, dirname, filename)
                with open(abs_path, 'rb') as f:
                    x_spam.append(f.read().split())
        else:
            for filename in os.listdir(os.path.join(path, dirname)):
                abs_path = os.path.join(path, dirname, filename)
                with open(abs_path, 'rb') as f:
                    x_ham.append(f.read().split())

# %%
len(x_ham)
# Out:
# 18219

# %%
File_1 = ('aaa', 'xyz', 'cccc', 'dddd', 'aaa')
File_2 = ('abc', 'aaa')

# %%
v = DictVectorizer()
v.fit_transform(Counter(f) for f in (File_1, Fil))
# Out:
# <2x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %%
v.vocabulary_
# Out:
# {'aaa': 0, 'xyz': 4, 'cccc': 2, 'dddd': 3, 'abc': 1}

# %%
x
# Out:
# ['From',
#  'exmh-workers-admin@redhat.com',
#  'Thu',
#  'Aug',
#  '22',
#  '12:36:23',
#  '2002',
#  'Return-Path:',
#  '<exmh-workers-admin@spamassassin.taint.org>',
#  'Delivered-To:',
#  'zzzz@localhost.netnoteinc.com',
#  'Received:',
#  'from',
#  'localhost',
#  '(localhost',
#  '[127.0.0.1])',
#  'by',
#  'phobos.labs.netnoteinc.com',
#  '(Postfix)',
#  'with',
#  'ESMTP',
#  'id',
#  'D03E543C36',
#  'for',
#  '<zzzz@localhost>;',
#  'Thu,',
#  '22',
#  'Aug',
#  '2002',
#  '07:36:16',
#  '-0400',
#  '(EDT)',
#  'Received:',
#  'from',
#  'phobos',
#  '[127.0.0.1]',
#  'by',
#  'localhost',
#  'with',
#  'IMAP',
#  '(fetchmail-5.9.0)',
#  'for',
#  'zzzz@localhost',
#  '(single-drop);',
#  'Thu,',
#  '22',
#  'Aug',
#  '2002',
#  '12:36:16',
#  '+0100',
#  '(IST)',
#  'Received:',
#  'from',
#  'listman.spamassassin.taint.org',
#  '(listman.spamassassin.taint.org',
#  '[66.187.233.211])',
#  'by',
#  'dogma.slashnull.org',
#  '(8.11.6/8.11.6)',
#  'with',
#  'ESMTP',
# ...

# %%
x.iloc[5].values
# Out:
# array(['Received: from phobos [127.0.0.1]', nan], dtype=object)

# %%
File_1 = ['aaa', 'xyz', 'cccc', 'dddd', 'aaa']
File_2 = ['aaa', 'llll']

v = DictVectorizer()

# discover corpus and vectorize file word frequencies in a single pass
X = v.fit_transform(Counter(f) for f in (File_1, File_2))
v.vocabulary_
# Out:
# {'aaa': 0, 'xyz': 4, 'cccc': 1, 'dddd': 2, 'llll': 3}
